# %%
# %run knn_project/eda.py
# Out:
# === --------------------------Iris Dataset EDA---------------------------------------- ===
# Classes: ['setosa' 'versicolor' 'virginica']
# Feature shape: (150, 4)
# === ----------------------------------Wine Dataset EDA------------------------------------------- ===
# Classes: [1 2 3]
# Feature shape: (178, 13)

# %%
# %run knn_project/main.py
# Out:
# Iris Dataset Results ->
# K = 1  → Accuracy: 96.67%
# K = 3  → Accuracy: 100.00%
# K = 5  → Accuracy: 100.00%
# K = 7  → Accuracy: 100.00%
# K = 9  → Accuracy: 100.00%
# K = 11 → Accuracy: 100.00%
# K = 15 → Accuracy: 100.00%
#
# Best K for Iris dataset: 3
# Highest Accuracy: 100.00%
# Wine Dataset Results ->
# K = 1  → Accuracy: 94.29%
# K = 3  → Accuracy: 94.29%
# K = 5  → Accuracy: 94.29%
# K = 7  → Accuracy: 94.29%
# K = 9  → Accuracy: 94.29%
# K = 11 → Accuracy: 94.29%
# K = 15 → Accuracy: 97.14%
#
# Best K for Wine dataset: 15
# Highest Accuracy: 97.14%
# Summary
# Iris Dataset → Best K = 3, Accuracy = 100.00%
# Wine Dataset → Best K = 15, Accuracy = 97.14%
